# %%
import pandas as pd

df = pd.read_csv('Tokopedia.csv')
df
# Out:
#                                                Ulasan
# 0   Sudah 2 kali beli dan produk tetap bagus 👌🏽 ka...
# 1   Barang sampai dengan selamat cuma sempat khawa...
# 2           nice push valo silver ke diamond seharian
# 3   Sudah dipakai 3 bulan, aman lancar gak ada mas...
# 4         sesuai deskripsi, packing rapi, semoga awet
# 5                                             Lumayan
# 6   Mouse premium dengan embel-embel gaming yang t...
# 7   Packaging rapi, barang tiba dengan selamat, pe...
# 8   quality nya mengenaskan banget dibanding sama ...
# 9   Fast response, pengiriman cepat, mouse nya the...
# 10  The tactile feedback of the switches enhances ...
# 11                                               good
# 12      pengiriman cepat barang bagus dan berfungsi 👍
# 13  Kualitas Packing baik. Sempat kaget ada yang r...
# 14                                                 ok
# 15  ini mouse terbaik, semoga bisa awet dan perfor...
# ...
